# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# Parámetros
vocab_size = 10        # Simulamos un vocabulario pequeño con 10 palabras
embedding_dim = 4      # Cada palabra se representará con un vector de tamaño 4

# Crear capa de embedding
embedding = nn.Embedding(vocab_size, embedding_dim)

# Simular una secuencia de 5 palabras (por índice)
example_sequence = torch.tensor([2, 5, 0, 3, 8])  # índices en el vocabulario

# Obtener vectores de embedding
embedded = embedding(example_sequence)  # Shape: [5, 4]

# Mostrar valores de embedding
print("🔢 Secuencia de índices:")
print(example_sequence)
print("\n📚 Vectores embebidos (una fila por palabra):")
print(embedded)

# Visualizar cada dimensión del embedding
plt.figure(figsize=(8, 4))
for i in range(embedding_dim):
    plt.plot(embedded[:, i].detach().numpy(), label=f'Dim {i}')
plt.title("Representación embebida de la secuencia")
plt.xlabel("Posición en la secuencia")
plt.ylabel("Valor del embedding")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 🔢 Secuencia de índices:
# tensor([2, 5, 0, 3, 8])
#
# 📚 Vectores embebidos (una fila por palabra):
# tensor([[-1.3761, -0.2891, -1.8123,  0.6135],
#         [-0.6873,  0.0201,  1.7741, -0.6369],
#         [ 0.7212,  1.3533,  1.0041, -1.5667],
#         [ 0.6521, -1.5586,  0.3619, -0.0185],
#         [-0.0782,  0.8863, -0.5355,  0.4819]], grad_fn=<EmbeddingBackward0>)
